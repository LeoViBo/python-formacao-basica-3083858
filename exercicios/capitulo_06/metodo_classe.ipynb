# %% [markdown]
# - Crie uma classe

# %% [markdown]
# - Estabeleça variáveis privadas no construtor

# %% [markdown]
# - Crie um método get, que retorne uma das variáveis privadas

# %% [markdown]
# - Crie um método set, que modifique uma das variáveis privadas

# %% [markdown]
# - Instancie a classe e imprima na tela a variável antes e depois da modificação

# %%
class classe_legal():
    def __init__(self):
        self._valor = 2
        self._legal = "legal"
    
    def getValor(self):
        return self._valor
    def getLegal(self):
        return self._legal

    def setValor(self, val):
        self._valor = val
        if self._valor%2==0:
            self._legal="legal"
        else:
            self._legal="não legal"

variavel = classe_legal()
print(variavel.getValor())
print(variavel.getLegal())
variavel.setValor(3)
print(variavel.getValor())
print(variavel.getLegal())
# Out:
# 2
# legal
# 3
# não legal

# %% [markdown]
# - Defina uma função com 1 argumento

# %% [markdown]
# - Defina uma função com 2 argumentos

# %%
def func1(val:int):
    return val

def func2(val1:int, val2:str):
    return print(f"{val1} é {val2}")

print(func1(1))
func2(1,"legal")
# Out:
# 1
# 1 é legal

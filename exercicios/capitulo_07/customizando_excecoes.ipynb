# %% [markdown]
# - Imagine que você está criando um servidor web e customize exceções para o código

# %% [markdown]
# - Simule a aplicação de uma exceção customizada no código

# %%
class HttpException(Exception):
    status = None
    text = None

    def __init__(self):
        super().__init__(f'{self.text} ({self.status})')

class Unauthorized(HttpException):
    status = 401
    text = 'Acesso não autorizado'

def raiseUnauthorizedError():
    raise Unauthorized()

raiseUnauthorizedError()
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# Cell In[3], line 15
#      12 def raiseUnauthorizedError():
#      13     raise Unauthorized()
# ---> 15 raiseUnauthorizedError()
#
# Cell In[3], line 13, in raiseUnauthorizedError()
#      12 def raiseUnauthorizedError():
# ---> 13     raise Unauthorized()
#
# Unauthorized: Acesso não autorizado (401)

# %% [markdown]
# - Some dois números e verifique o tipo de dado do resultado

# %% [markdown]
# - Crie uma operação com números decimais, usando a biblioteca Decimal

# %%
var = 1+2
print(type(var))
# Out:
# <class 'int'>

# %%
from decimal import *

var1 = Decimal('0.10')
var2 = Decimal('0.30')
var_dec = var1+var1+var1-var2
print(var_dec)
# Out:
# 0.00

# %% [markdown]
# - Crie uma lista

# %%
lista = ["var","legal","true"]

# %% [markdown]
# - Usando o recurso dictionary comprehension, crie um dicionário cuja a chave é o comprimento do item e o valor, o próprio item da lista.

# %%
dict_var = {f"{len(item)}-{item[0]}": item for item in lista}
print(dict_var)
# Out:
# {'3-v': 'var', '5-l': 'legal', '4-t': 'true'}

# %% [markdown]
# - Crie uma lista de tuplas

# %%
tuplas = [(1,2),(3,4),(5,6)]

# %% [markdown]
# - Usando o recurso dictionary comprehension, crie um dicionário cuja a chave é o primeiro item da tupla e o valor, o segundo

# %%
dict_tuplas = {chave:valor for (chave, valor) in tuplas}
print(dict_tuplas)
# Out:
# {1: 2, 3: 4, 5: 6}

# %% [markdown]
# - Crie um dicionário

# %%
dict_legal = {"val": 1, "val2": 2, "val3": 3}

# %% [markdown]
# - Usando o recurso dictionary comprehension, crie um novo dicionário cuja a chave é uma maniputação do valor

# %%
novo_dict = {f"{chave*2}":item*2 for (chave, item) in dict_legal.items()}
print(novo_dict)
# Out:
# {'valval': 2, 'val2val2': 4, 'val3val3': 6}

# %% [markdown]
# - Usando o recurso dictionary comprehension, crie um dicionário só com chaves com commprimento menor ou igual a 3

# %%
new_dict = {chave:item for (chave, item) in dict_legal.items() if len(chave)<=3}
print(new_dict)
# Out:
# {'val': 1}
